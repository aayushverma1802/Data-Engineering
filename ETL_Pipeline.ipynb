# %%
from databricks.connect import DatabricksSession
from pyspark.sql import functions as F

spark = DatabricksSession.builder.getOrCreate()

df = spark.table("samples.bakehouse.sales_transactions")
df.cache()  # optional: reuse in notebook while experimenting; unpersist() when done
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 spark = DatabricksSession.builder.getOrCreate()
#       6 df = spark.table("samples.bakehouse.sales_transactions")
# ----> 7 df.cache()  # optional: reuse in notebook while experimenting; unpersist() when done
#
# File c:\ProgramData\Anaconda3\Lib\site-packages\pyspark\sql\connect\dataframe.py:2193, in DataFrame.cache(self)
#    2192 def cache(self) -> ParentDataFrame:
# -> 2193     return self.persist()
#
# File c:\ProgramData\Anaconda3\Lib\site-packages\pyspark\sql\connect\dataframe.py:2200, in DataFrame.persist(self, storageLevel)
#    2195 def persist(
#    2196     self,
#    2197     storageLevel: StorageLevel = (StorageLevel.MEMORY_AND_DISK_DESER),
#    2198 ) -> ParentDataFrame:
#    2199     relation = self._plan.plan(self._session.client)
# -> 2200     self._session.client._analyze(
# ...

# %%
df.printSchema()
print(df.coulmns)
df.show(5,truncate=False)
df.select("transactionID","dateTime","franchiseID","quantity","unitPrice","totalPrice","cardNumber").show(5,truncate=False)
# Out:
# root
#  |-- transactionID: long (nullable = true)
#  |-- customerID: long (nullable = true)
#  |-- franchiseID: long (nullable = true)
#  |-- dateTime: timestamp (nullable = true)
#  |-- product: string (nullable = true)
#  |-- quantity: long (nullable = true)
#  |-- unitPrice: long (nullable = true)
#  |-- totalPrice: long (nullable = true)
#  |-- paymentMethod: string (nullable = true)
#  |-- cardNumber: long (nullable = true)
#
# Column<'coulmns'>
# +-------------+----------+-----------+--------------------------+----------------------+--------+---------+----------+-------------+----------------+
# |transactionID|customerID|franchiseID|dateTime                  |product               |quantity|unitPrice|totalPrice|paymentMethod|cardNumber      |
# +-------------+----------+-----------+--------------------------+----------------------+--------+---------+----------+-------------+----------------+
# ...
